# %%
from google.colab import drive

# Montar Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.chdir('/content/drive/MyDrive/Qtaim_residuos')

# Obtener la ruta de la carpeta actual
ruta_actual = os.getcwd()

# Reemplazar parte de la ruta con la nueva carpeta
carpeta_nueva = "nueva_carpeta"
ruta_nueva = ruta_actual.replace("carpeta_actual", carpeta_nueva)

# Cambiar el directorio actual a la nueva ruta
os.chdir(ruta_nueva)

# %%
def interactions_detector(df,name_compound):
  import seaborn as sns
  import matplotlib.pyplot as plt

  heatmap_data = []

  for i in range(len(df)):
      Residues = str(df.iloc[i, 3]) +" "+ str(df.iloc[i, 4])
      rho = float(df.iloc[i, 11])
      heatmap_data.append([Residues, rho])

  heatmap_df = pd.DataFrame(heatmap_data, columns=['Residues',name_compound])
  heatmap_df = heatmap_df.groupby('Residues').sum().reset_index()

  return(heatmap_df)

# %%
def process_dataframe(df,Lig):
  # Iterar sobre las filas del DataFrame
  for index, row in df.iterrows():
      j = row[3]
      k = row[9]
      if j == k:
          # Eliminar la fila que cumple la condición
          df = df.drop(index)

  # Restablecer los índices del DataFrame después de eliminar las filas
  df = df.reset_index(drop=True)

  column_names = ['Col0', 'Col1', 'Col2', 'Col3', 'Col4', 'Col5', 'Col6', 'Col7', 'Col8', 'Col9', 'Col10', 'Col11', 'Col12', 'Col13']
  rearange_df = pd.DataFrame(columns=column_names)

  for i in range(len(df[0])):
      j = df.iloc[i, 3]
      if j == Lig:
          col0 = df.iloc[i, 6]
          col1 = df.iloc[i, 7]
          col2 = df.iloc[i, 8]
          col3 = df.iloc[i, 9]
          col4 = df.iloc[i, 10]
          col5 = df.iloc[i, 5]
          col6 = df.iloc[i, 0]
          col7 = df.iloc[i, 1]
          col8 = df.iloc[i, 2]
          col9 = df.iloc[i, 3]
          col10 = df.iloc[i, 4]
          col11 = df.iloc[i, 11]
          col12 = df.iloc[i, 12]
          col13 = df.iloc[i, 13]

          row = [col0, col1, col2, col3, col4, col5, col6, col7, col8, col9, col10, col11, col12, col13]
          rearange_df.loc[len(rearange_df)] = row
      else:
          col0 = df.iloc[i, 0]
          col1 = df.iloc[i, 1]
          col2 = df.iloc[i, 2]
          col3 = df.iloc[i, 3]
          col4 = df.iloc[i, 4]
          col5 = df.iloc[i, 5]
          col6 = df.iloc[i, 6]
          col7 = df.iloc[i, 7]
          col8 = df.iloc[i, 8]
          col9 = df.iloc[i, 9]
          col10 = df.iloc[i, 10]
          col11 = df.iloc[i, 11]
          col12 = df.iloc[i, 12]
          col13 = df.iloc[i, 13]
          row = [col0, col1, col2, col3, col4, col5, col6, col7, col8, col9, col10, col11, col12, col13]
          rearange_df.loc[len(rearange_df)] = row

  rearange_df.reset_index(drop=True, inplace=True)
  df2 = rearange_df.drop("Col5", axis=1)
  # Verificar duplicados en todas las columnas
  duplicates = df2.duplicated()

  # Obtener índices de filas duplicadas
  duplicate_indices = df2[duplicates].index

  # Eliminar filas duplicadas
  df2 = df2.drop(duplicate_indices)

  # Restablecer los índices del DataFrame después de eliminar las filas duplicadas
  df2 = df2.reset_index(drop=True)
  return df2

# %%
import pandas as pd

# %% [markdown]
# # **Heatmap1**

# %%
nombre_archivo = 'CPsInfo_9MT.txt'

# Dividir el nombre del archivo usando el carácter '_'
split_nombre = nombre_archivo.split('_')
split_nombre = split_nombre[1]
split_nombre = split_nombre.split(".")
# Seleccionar el elemento después del '_' y antes de '.txt'
name_file = split_nombre[0]

print(name_file)
# Out:
# 9MT

# %%
# Leer el archivo en un DataFrame de pandas
df = pd.read_csv(nombre_archivo, delimiter='\t', header=None)
df2=process_dataframe(df,"M9T") #cambiar nombre Lig
df2.head()
# Out:
#    Col0 Col1  Col2 Col3  Col4  Col6 Col7  Col8 Col9  Col10     Col11  \
# 0    44    C   350  ARG   193   105    O   387  M9T    309  0.005620
# 1    61    H   342  ALA   192   107    H   419  M9T    309  0.001622
# 2    54    H   341  ALA   192   131    H   423  M9T    309  0.001132
# 3    61    H   342  ALA   192   154    H   416  M9T    309  0.001417
# 4    93    H    38  GLY    43   135    H   420  M9T    309  0.009578
#
#       Col12     Col13
# 0  0.022620  0.027955
# 1  0.005413  0.007540
# 2  0.003746  0.004732
# 3  0.004569  0.005976
# 4  0.035190  0.056533

# %%
hm1=interactions_detector(df2,name_file)
hm1.head()
# Out:
#   Residues       9MT
# 0  ALA 192  0.013728
# 1   ALA 68  0.049306
# 2  ARG 193  0.042059
# 3  ASP 124  0.003038
# 4  CYS 120  0.110672

# %% [markdown]
# # **Heatmap2**

# %%
nombre_archivo = 'CPsInfo_bergamal.txt'

# Dividir el nombre del archivo usando el carácter '_'
split_nombre = nombre_archivo.split('_')
split_nombre = split_nombre[1]
split_nombre = split_nombre.split(".")
# Seleccionar el elemento después del '_' y antes de '.txt'
name_file = split_nombre[0]

print(name_file)
# Out:
# bergamal

# %%
# Leer el archivo en un DataFrame de pandas
df = pd.read_csv(nombre_archivo, delimiter='\t', header=None)
df3=process_dataframe(df,"UNL") #cambiar nombre Lig
df3.head()
# Out:
#    Col0 Col1  Col2 Col3  Col4  Col6 Col7  Col8 Col9  Col10     Col11  \
# 0    70    H   294  ARG   193   106    H   349  UNL    309  0.004193
# 1    99    H    24  GLY    43   117    H   348  UNL    309  0.004992
# 2    84    H   297  ARG   193   137    H   351  UNL    309  0.003925
# 3    96    H    49  VAL    50   126    H   347  UNL    309  0.003186
# 4   122    N    20  GLY    43   126    H   347  UNL    309  0.002268
#
#       Col12     Col13
# 0  0.014491  0.018745
# 1  0.018374  0.026952
# 2  0.012945  0.017497
# 3  0.011049  0.013819
# 4  0.009022  0.010746

# %%
hm2=interactions_detector(df3,name_file)
hm2.head()
# Out:
#   Residues  bergamal
# 0  ARG 193  0.038703
# 1  ASP 124  0.047127
# 2   GLY 43  0.027396
# 3  LEU 177  0.060796
# 4   LEU 42  0.076593

# %% [markdown]
# # **Heatmap3**

# %%
nombre_archivo = 'CPsinfo_guaiene.txt'

# Dividir el nombre del archivo usando el carácter '_'
split_nombre = nombre_archivo.split('_')
split_nombre = split_nombre[1]
split_nombre = split_nombre.split(".")
# Seleccionar el elemento después del '_' y antes de '.txt'
name_file = split_nombre[0]

print(name_file)
# Out:
# guaiene

# %%
# Leer el archivo en un DataFrame de pandas
df = pd.read_csv(nombre_archivo, delimiter='\t', header=None)
df3=process_dataframe(df,"UNL") #cambiar nombre Lig
df3.head()
# Out:
#    Col0 Col1  Col2 Col3  Col4  Col6 Col7  Col8 Col9  Col10     Col11  \
# 0    58    H   267  ARG   193   112    H   334  UNL    309  0.005423
# 1    71    H   269  ARG   193   129    C   314  UNL    309  0.009628
# 2   131    H   214  PHE   189   122    H   335  UNL    309  0.005809
# 3    96    H    24  GLY    43   151    H   320  UNL    309  0.000957
# 4   131    H   214  PHE   189   176    H   329  UNL    309  0.003572
#
#       Col12     Col13
# 0  0.018769  0.023760
# 1  0.036881  0.047366
# 2  0.020955  0.032227
# 3  0.003177  0.004233
# 4  0.012493  0.016776

# %%
hm3=interactions_detector(df3,name_file)
hm3 = hm3.rename(columns={hm3.columns[1]: 'alpha_guaiene'})
hm3.head()
# Out:
#   Residues  alpha_guaiene
# 0  ALA 192       0.002390
# 1   ALA 68       0.000628
# 2  ARG 193       0.065362
# 3  ASP 124       0.015196
# 4  GLY 123       0.032221

# %%
import pandas as pd

# Unir los DataFrames en función de la columna "Residues"
merged_df = pd.merge(hm1, hm2, on='Residues', how='outer')
merged_df = pd.merge(merged_df, hm3, on='Residues', how='outer')

# Completar los valores faltantes (NaN) con ceros
merged_df.fillna(0, inplace=True)

# Imprimir el DataFrame resultante
merged_df
# Out:
#    Residues       9MT  bergamal  alpha_guaiene
# 0   ALA 192  0.013728  0.000000       0.002390
# 1    ALA 68  0.049306  0.000000       0.000628
# 2   ARG 193  0.042059  0.038703       0.065362
# 3   ASP 124  0.003038  0.047127       0.015196
# 4   CYS 120  0.110672  0.000000       0.000000
# 5   CYS 121  0.012388  0.000000       0.000000
# 6   GLU 118  0.046746  0.000000       0.000000
# 7   GLY 123  0.047300  0.000000       0.032221
# 8    GLY 43  0.035190  0.027396       0.003177
# 9   LEU 177  0.056527  0.060796       0.059520
# 10   LEU 42  0.056638  0.076593       0.071193
# 11   LYS 70  0.083576  0.000000       0.000000
# 12  PHE 189  0.043245  0.073711       0.072402
# 13  THR 117  0.026579  0.000000       0.000000
# 14  TYR 119  0.043562  0.000000       0.000000
# 15  VAL 101  0.012287  0.000000       0.000000
# 16   VAL 50  0.119525  0.033735       0.081700

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# Establecer la columna "Residues" como índice
merged_df.set_index('Residues', inplace=True)

# Transponer el DataFrame
transposed_df = merged_df.transpose()

# Crear la figura con tamaño personalizado
plt.figure(figsize=(10, 4))

# Crear la escala de color personalizada
colors = [(0.0, 'white'), (0.02, 'yellow'),(0.25,'green'),(0.5, 'blue'),(0.75,"orange") ,(1.0, 'red')]
custom_cmap = mcolors.LinearSegmentedColormap.from_list('CustomMap', colors)

# Obtener los límites para la escala de color
vmin = merged_df.values.min()
vmax = merged_df.values.max()

# Generar el heatmap con ejes intercambiados y ajustar la escala de color
sns.heatmap(transposed_df, cmap=custom_cmap, xticklabels=True, yticklabels=True, vmin=vmin, vmax=vmax,annot=True,annot_kws={'rotation': 90})

# Configurar etiquetas y título
plt.xlabel('')
plt.ylabel('')
plt.title('Csf1r')

# Girar las etiquetas del eje x
plt.xticks(rotation=90)

# Obtener las etiquetas del eje y
yticklabels = transposed_df.index.tolist()

# Ajustar las etiquetas del eje y girándolas
plt.gca().set_yticklabels(yticklabels, rotation=0)

# Obtener el número de filas y columnas
num_rows = merged_df.shape[0]
num_cols = merged_df.shape[1]

# Agregar líneas horizontales
for i in range(num_cols):
    plt.axhline(i, color='black', lw=0.5)

# Agregar líneas verticales
for j in range(num_rows):
    plt.axvline(j, color='black', lw=0.5)

plt.savefig('heatmap_compounds_csf1r_all_annot.pdf', format='pdf', bbox_inches='tight')

# Mostrar el heatmap
plt.show()
